# %% [markdown]
# # Creating graphs

# %% [markdown]
# Want graphs for each third of the averages
#
# - Things This Script Will Do:
#     - Display teams starting 5 stats over the course of the season
#         - Broken down in thirds
#         - Points, Assists, Rebounds formatted --> x.x/x.x/x.x
#     - Eventually want custom slicers implemented

# %%
import matplotlib.pyplot as plt
import numpy as np

# create data
x = [1,2,3,4,5]
y = [3,3,3,3,3]

# This is an example of a plot, from a website and I will be 
# attempting to incorporate my data to meet my needs
plt.plot(x, y, label = "line 1", linestyle="-")
plt.plot(y, x, label = "line 2", linestyle="--")
plt.plot(x, np.sin(x), label = "curve 1", linestyle="-.")
plt.plot(x, np.cos(x), label = "curve 2", linestyle=":")
plt.legend()
plt.show()
